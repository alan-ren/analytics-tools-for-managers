# %% [markdown]
# # Intro to SQL and Python

# %% [markdown]
# _Note: key terms will be bolded throughout this document._
#
# You're currently running a Jupyter notebook!
#
# This is an interactive coding environment that allows you to run Python code in **cells** as seen below.
#
# Try executing the cell below by clicking into it and pressing `SHIFT + ENTER`. You should see the text to the left of the cell, `In []`, update to `In [1]`. This number represents the order in which you've executed cells in your notebook.

# %%
# In Python, comments start with a hashtag at the beginning of a line
# This cell imports the psycopg2 library which we previously installed
# Importing a library allows us to use it during our current session
import psycopg2

# %% [markdown]
# We've successfully **imported** our library! For your reference, the `psycopg2` [library](https://www.psycopg.org/docs/) is an **open-source package** which allows us to interact with a live SQL database in our Python environment. Below, we're going to use this package to work with a popular open-source version of SQL called [Postgres](https://en.wikipedia.org/wiki/PostgreSQL).
#
# Before we get any further, if you're looking to get more comfortable with the syntax of Python, I'd recommend perusing the following interactive tutorials:
# - [Printing Hello, World!](https://www.learnpython.org/en/Hello%2C_World%21)
# - [Variables and Types](https://www.learnpython.org/en/Variables_and_Types)
# - [Lists](https://www.learnpython.org/en/Lists)
# - [Conditions](https://www.learnpython.org/en/Conditions)
# - [Loops](https://www.learnpython.org/en/Loops)
# - [Functions](https://www.learnpython.org/en/Loops)
#
# I'll do my best to explain various CS concepts in simple terms as we move along. The above tutorials should be considered _optional_ learning if you want to get better at working with Python syntax. Other optional content is formatted in italics below.
#
# Now — click into the cell below and hit `SHIFT + ENTER`. You should see the cell count increment to `In [2]`.

# %%
connection = psycopg2.connect(
    database="", # database name
    user="", # database user's username
    password="", # database user's password
    host="hbs.cm4xib1x9qhd.us-east-1.rds.amazonaws.com", # web address
    port='5432' # unique connection identifier 
)

# %% [markdown]
# What's going on in this cell?
#
# We're calling a **function** that exists in the `psycopg2` package called `connect()`. This function establishes a connection to a database somewhere on the web — in other words, it logs in!
#
# It accepts various **parameters** such as `database`, `user`, `password`, `host`, and `port`. *(You can optionally read more about ports [here](https://en.wikipedia.org/wiki/Port_(computer_networking)).)*
#
# We're **assigning** the result of this function execution to a **variable** which we have called `connection`. Note that we could call this variable whatever we want, such as `pizza`.
#
# The specific Postgres database that we're working with is one that I've set up on AWS for the purpose of this exercise. Once we've established this connection, we can now query the database!
#
# _If you're curious about how the `connect()` function works, the [documentation](https://www.psycopg.org/docs/connection.html?highlight=connect) for the `psycopg2` library explains this in more detail._

# %%
# First, we create a database cursor 
from psycopg2 import extras
cursor = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %% [markdown]
# What did we do here? If you said that we:
# - Called the `cursor()` function of our `connection`
# - Assigned the result of this function to a variable called `cursor`
#
# Then you're correct!
#
# _We conduct a separate import of the `extras` module from `psycopg2` so that the resulting `cursor` is formatted slightly neater than the default setting. You don't need to understand what's happening with the `cursor_factory` parameter; just know that it makes our life easier._
#
# Again, we could have called our `cursor` variable `ice_cream` if we wanted to. Note that the `connection.cursor()` function is explicitly defined in the documentation as part of the `connection` that is created by `psycopg2`.
#
# We would not be able to call `connection.ice_cream()` as that isn't a real thing. However, if we had stored the `connection` in a different variable, such as `pizza`, we would be able to call `pizza.cursor()`.
#
# _See the `psycopg2` [docs](https://www.psycopg.org/docs/cursor.html#cursor) for more details!_

# %% [markdown]
# ### Querying the database

# %% [markdown]
# ![Let's get down to business](https://pyxis.nymag.com/v1/imgs/433/898/17ff3bd1a1e20e75702cc4b1a99bc3430e-li-shang.2x.rsocial.w600.jpg)
#
# Now let's down to business!

# %% [markdown]
# Just kidding. Before we can query our database, we have to know what it actually looks like!
#
# A database is made up of many individual **tables**, each of which can be analogized to a spreadsheet. The **columns** of a table represent specific attributes, and the **rows** of a table represent individual objects.
#
# Let's construct a SQL query that looks at our database's metadata. This will get us a list of all the tables in our database.
#
# So ... what **clauses** make up a SQL query? Queries that involve **reading data** (often what a PM is doing) have the following components:
# 1. `SELECT column1, column2, ...`
# 2. `FROM table_name`
# 3. `WHERE condition;`
#
# **Don't forget the semicolon!**
#
# Given this structure, we can construct a query that retrieves all of the tables in our database:
# ```
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema='public';
# ```
#
# How did we know to construct our query like this? The [Postgres documentation](https://www.postgresql.org/docs/current/infoschema-tables.html) outlines all of this information about how metadata tables are standardized. Yup, the answer is "Read the manual".
#
# _Looking at the docs, we see that there is a standard `table_name` column which exists on the standard `information_schema.tables` metadata table.  However, since Postgres has a lot of private metadata tables, we should also specify that we only want tables where the `table_schema` column is public, as that represents tables which store real data._
#
# Now, how do we execute this SQL query against the database using our `cursor` which we constructed above?

# %%
# Call the cursor.execute() function which takes one parameter, our query
# In Python, multi-line text strings go in between triple-quotes
cursor.execute(
    """
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'public';
    """
)

# After executing the query, we MUST also call cursor.fetchall()
# This returns the results of our query, otherwise nothing happens
cursor.fetchall()
# Out:
# [['titles'], ['people'], ['revenues'], ['roles']]

# %% [markdown]
# We got our results! Why do they look kind of funky?
#
# Well, the square brackets in Python represent a `list` data type. We simply received the results of our function call as a nested list of lists.
#
# Now, how do we figure out what the columns are on each of these tables?
#
# We perform a similar metadata query on another Postgres metadata table (this time, `information_schema.columns` — see [docs](https://www.postgresql.org/docs/current/infoschema-columns.html)) and we specifically add the condition that `table_name = 'titles'`. Note that the name of the table, being a text string, must be enclosed in quotes.
#
# Let's run this query for each of our tables!

# %%
cursor.execute(
    """
    SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'public' AND table_name = 'titles';
    """
)
cursor.fetchall()
# Out:
# [['id'],
#  ['adaptation'],
#  ['domestic_gross'],
#  ['franchise'],
#  ['genre'],
#  ['international_gross'],
#  ['mpaa_rating'],
#  ['plot'],
#  ['poster_url'],
#  ['production_budget'],
#  ['runtime'],
#  ['metascore'],
#  ['rt_critics'],
#  ['rt_users'],
#  ['imdb_score'],
#  ['theatrical_release'],
#  ['title'],
#  ['three_d']]

# %%
cursor.execute(
    """
    SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'public' AND table_name = 'people';
    """
)
cursor.fetchall()
# Out:
# [['id'], ['name'], ['gender'], ['race'], ['birthday']]

# %%
cursor.execute(
    """
    SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'public' AND table_name = 'roles';
    """
)
cursor.fetchall()
# Out:
# [['title_id'], ['person_id'], ['role_type']]

# %%
cursor.execute(
    """
    SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'public' AND table_name = 'revenues';
    """
)
cursor.fetchall()
# Out:
# [['title_id'], ['week_number'], ['gross'], ['theaters']]

# %% [markdown]
# Have you guessed what data is contained in our database? It's movies!
#
# We have a table of `titles` corresponding to individual movies and a table of `people` corresponding to actors and directors.
#
# But why do we have a table of `roles` and `revenues`? This gets at a fundamental question of **data modeling** — where do you store data that pertains to multiple tables?
#
# Consider that one row in the `titles` table corresponds to one movie, and one row in the `people` database corresponds to one actor. What happens if we store the cast in `titles` and it changes? What happens if we store an actor's filmography in `people` and it changes? What happens if we store the data in both locations? How much work would it be to update the data, and which table contains the source of truth?
#
# Well, because our movies have relationships with actors, we can create a completely separate table that represents the relationship between `titles` and `people`. This third table is the single source of truth!
#
# Notice that every movie in `titles` has an `id` property. This is a unique value which we call a **primary key**, which allows us to differentiate between different movies. Similarly, different actors in `people` have unique `id` values. When we want to capture that Tom Holland is starring in a new Spider-Man movie, we can use Tom Holland's `id` from `people` and the movie's `id` from `titles` to create a new entry in `roles`.
#
# As you can see, the `roles` table has `title_id` and `person_id` columns. These are considered **foreign keys** because they correspond to the primary keys of other tables.
#
# Similarly, we store new weekly revenue numbers in the `revenues` table by associating each entry with a movie's `title_id` foreign key.

# %% [markdown]
# ### Some simple examples

# %%
# Retrieve all columns for movies with a runtime of over 200 minutes
cursor.execute(
    """
    SELECT *
    FROM titles
    WHERE runtime > 200;
    """
)
cursor.fetchall()
# Out:
# [['aa2b71bf-ac03-4e6a-845b-0f1000026553',
#   'false',
#   Decimal('145526'),
#   None,
#   'Biography',
#   Decimal('145526'),
#   'Unrated',
#   "Ilich Ramirez Sanchez, aka 'Carlos,' is a Venezuelan-born Marxist revolutionary who aligns himself with the Palestinian cause and becomes the world's most notorious terrorist. He leads assaults on the meeting of OPEC ministers, taking them hostage and flying them from country to country seeking asylum, one of the most daring acts of terrorism in history. From his earliest days as an apprentice in the revolutionary movement to his subsequent downfall, Carlos becomes a figure of legend.",
#   'http://ia.media-imdb.com/images/M/MV5BMTkwNDU4Mzc4OV5BMl5BanBnXkFtZTcwMzEyMTA3NQ@@._V1_SX300.jpg',
#   Decimal('18000000'),
#   Decimal('333'),
#   Decimal('94'),
#   Decimal('94'),
#   Decimal('85'),
#   Decimal('7.7'),
#   datetime.datetime(2010, 10, 15, 0, 0),
#   'Carlos',
#   False],
#  ['b3dc2642-03d2-4d50-9b2b-fe215be4429a',
#   'novel',
#   Decimal('12882934'),
#   'Gettysburg',
#   'Drama',
#   Decimal('12882934'),
#   'PG-13',
#   'The rise and fall of legendary war hero Thomas "Stonewall" Jackson as he leads the Confederacy to great success against the Union from 1861 to 1863. Prequel to the 1993 classic "Gettysburg".',
#   'http://ia.media-imdb.com/images/M/MV5BMTU1NzExNjU3OF5BMl5BanBnXkFtZTYwNzc0MDg5._V1_SX300.jpg',
#   Decimal('56000000'),
#   Decimal('229'),
#   Decimal('30'),
#   Decimal('8'),
#   Decimal('63'),
#   Decimal('6.3'),
#   datetime.datetime(2003, 2, 21, 0, 0),
#   'Gods and Generals',
#   False],
#  ['f6c19176-5de8-4207-9b94-c4ff73404ec8',
#   'novel',
#   Decimal('377027325'),
#   'Middle Earth',
#   'Adventure',
#   Decimal('377027325'),
#   'PG-13',
#   "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#   'http://ia.media-imdb.com/images/M/MV5BMjE4MjA1NTAyMV5BMl5BanBnXkFtZTcwNzM1NDQyMQ@@._V1_SX300.jpg',
#   Decimal('94000000'),
#   Decimal('201'),
#   Decimal('94'),
#   Decimal('95'),
#   Decimal('86'),
#   Decimal('8.9'),
#   datetime.datetime(2003, 12, 17, 0, 0),
#   'The Lord of the Rings: The Return of the King',
#   False],
#  ['f43750cb-c2d5-4914-a087-d11be1b42447',
#   'nonfiction',
#   Decimal('48200000'),
#   None,
#   'Biography',
#   Decimal('48200000'),
#   'PG-13',
#   'Biograpical epic of Malcolm X, the legendary African American leader. Born Malcolm Little, his father (a Garveyite Baptist minister) was killed by the Ku Klux Klan. Malcolm became a gangster, and while in jail discovered the Nation of Islam writings of Elijah Muhammad. He preaches the teachings when let out of jail, but later on goes on a pilgrimage to the city of Mecca, there he converts to the original Islamic religion and becomes a Sunni Muslim and changes his name to El-Hajj Malik Al-Shabazz. He is assassinated on February 21, 1965 and dies a Muslim martyr.',
#   'http://ia.media-imdb.com/images/M/MV5BOTc4NzgxMDc4MF5BMl5BanBnXkFtZTgwOTA4MDc3NjE@._V1_SX300.jpg',
#   Decimal('33000000'),
#   Decimal('201'),
#   Decimal('72'),
#   Decimal('91'),
#   Decimal('91'),
#   Decimal('7.7'),
#   datetime.datetime(1992, 11, 18, 0, 0),
#   'Malcolm X',
#   False],
#  ['69a53866-06d6-44a5-80c2-b209ff3c1ed5',
#   'novel',
#   Decimal('182207973'),
#   'Gettysburg',
#   'Drama',
#   Decimal('182207973'),
#   'PG',
#   'In 1863, the Northern and Southern forces fight at Gettysburg in the decisive battle of the American Civil War.',
#   'http://ia.media-imdb.com/images/M/MV5BMTQwMjE3NDg4NV5BMl5BanBnXkFtZTcwMDI3MTE2Mw@@._V1_SX300.jpg',
#   Decimal('65000000'),
#   Decimal('271'),
#   None,
#   Decimal('80'),
#   Decimal('89'),
#   Decimal('7.7'),
#   datetime.datetime(1993, 10, 8, 0, 0),
#   'Gettysburg',
#   False]]

# %%
# Retrieve Tom Holland
cursor.execute(
    """
    SELECT *
    FROM people
    WHERE name = 'Tom Holland';
    """
)
cursor.fetchall()
# Out:
# [['4e7b6c16-0381-422a-85dd-91a2cd7a38d5',
#   'Tom Holland',
#   'Male',
#   'White',
#   datetime.datetime(1996, 6, 1, 0, 0)]]

# %%
# Retrieve all of Tom Holland's movies
cursor.execute(
    """
    SELECT 
        t.id, 
        t.adaptation,
        t.domestic_gross,
        t.franchise,
        t.genre,
        t.international_gross,
        t.mpaa_rating,
        t.plot,
        t.poster_url,
        t.production_budget,
        t.runtime,
        t.metascore,
        t.rt_critics,
        t.rt_users,
        t.imdb_score,
        t.theatrical_release,
        t.title,
        t.three_d
    FROM titles AS t
    JOIN roles ON roles.title_id = t.id
    WHERE roles.person_id = '4e7b6c16-0381-422a-85dd-91a2cd7a38d5';
    """
)
cursor.fetchall()
# Out:
# [['07428f8a-d0c4-4d43-875f-237d4b281a74',
#   'nonfiction',
#   Decimal('25020758'),
#   None,
#   'Action',
#   Decimal('25020758'),
#   'PG-13',
#   "A recounting of a New England whaling ship's sinking by a giant whale in 1820, an experience that later inspired the great novel Moby-Dick.",
#   'http://ia.media-imdb.com/images/M/MV5BMjA5NzUwODExM15BMl5BanBnXkFtZTgwNjM0MzE4NjE@._V1_SX300.jpg',
#   Decimal('100000000'),
#   Decimal('121'),
#   Decimal('47'),
#   Decimal('42'),
#   Decimal('56'),
#   Decimal('7'),
#   datetime.datetime(2015, 12, 11, 0, 0),
#   'In the Heart of the Sea',
#   True],
#  ['bff03ce2-971c-4ac5-b301-c62b9e30c394',
#   'false',
#   Decimal('19019882'),
#   None,
#   'Drama',
#   Decimal('19019882'),
#   'PG-13',
#   'A regular family - Maria (Naomi Watts), Henry (Ewan McGregor) and their three kids - travel to Thailand to spend Christmas. They get an upgrade to a villa on the coastline. After settling in and exchanging gifts, they go to the pool, like so many other tourists. A perfect paradise vacation until a distant noise becomes a roar. There is no time to escape from the tsunami; Maria and her eldest are swept one way, Henry and the youngest another. Who will survive, and what will become of them?',
#   'http://ia.media-imdb.com/images/M/MV5BMjA5NTA3NzQ5Nl5BMl5BanBnXkFtZTcwOTYxNjY0OA@@._V1_SX300.jpg',
#   Decimal('45000000'),
#   Decimal('113'),
#   Decimal('73'),
#   Decimal('81'),
#   Decimal('84'),
#   Decimal('7.6'),
#   datetime.datetime(2012, 12, 21, 0, 0),
#   'The Impossible',
#   False],
#  ['a2071abf-fa5b-408d-a6cb-1b33a126d195',
#   'comic',
#   Decimal('408084349'),
#   'Marvel Cinematic Universe',
#   'Action',
#   Decimal('408084349'),
#   'PG-13',
#   "With many people fearing the actions of super heroes, the government decides to push for the Hero Registration Act, a law that limits a hero's actions. This results in a division in The Avengers. Iron Man stands with this Act, claiming that their actions must be kept in check otherwise cities will continue to be destroyed, but Captain America feels that saving the world is daring enough and that they cannot rely on the government to protect the world. This escalates into an all-out war between Team Iron Man (Iron Man, Black Panther, Vision, Black Widow, War Machine, and Spider-Man) and Team Captain America (Captain America, Bucky Barnes, Falcon, Scarlet Witch, Hawkeye, and Ant Man) while a new villain emerges.",
#   'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQ0MTgyNjAxMV5BMl5BanBnXkFtZTgwNjUzMDkyODE@._V1_SY1000_CR0,0,674,1000_AL_.jpg',
#   Decimal('250000000'),
#   Decimal('147'),
#   Decimal('75'),
#   Decimal('90'),
#   Decimal('90'),
#   Decimal('8.2'),
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'Captain America: Civil War',
#   True],
#  ['4fe63c90-8105-44b6-b425-c26ac0de42c5',
#   'comic',
#   None,
#   'Marvel Cinematic Universe',
#   'Action',
#   None,
#   'Unrated',
#   'A young Peter Parker/Spider-Man, who made his sensational debut in Captain America: Civil War, begins to navigate his newfound identity as the web-slinging superhero in Spider-Man: Homecoming. Thrilled by his experience with the Avengers, Peter returns home, where he lives with his Aunt May, under the watchful eye of his new mentor Tony Stark, Peter tries to fall back into his normal daily routine - distracted by thoughts of proving himself to be more than just your freindly neighborhood Spider-Man - but when the Vulture emerges as a new villain, everything that Peter holds most important will be threatened.',
#   'https://images-na.ssl-images-amazon.com/images/M/MV5BNDUzOTE5OTk1NF5BMl5BanBnXkFtZTgwNzgwNzA4MDI@._V1_UX182_CR0,0,182,268_AL_.jpg',
#   Decimal('160000000'),
#   Decimal('87'),
#   None,
#   Decimal('85'),
#   None,
#   None,
#   datetime.datetime(2017, 7, 7, 0, 0),
#   'Spider-Man: Homecoming',
#   True]]

# %% [markdown]
# It's worth going into some detail as to how we performed this last query.
#
# Recall from above that there are three clauses to a SQL query:
# 1. `SELECT column1, column2, ...`
# 2. `FROM table_name`
# 3. `WHERE condition;`
#
# What happens when we want to query all of Tom Holland's movies? We need to query information from `titles`, `roles`, and `people`!
#
# First, we found that Tom Holland's `id` in the `people` table is: `'4e7b6c16-0381-422a-85dd-91a2cd7a38d5'`.
#
# Then, we constructed a query that **joined** the `titles` and `roles` tables. Recall that `titles.id` is a foreign key for `roles.title_id`. This means that we can perform a `JOIN` operation that combines the two tables where the values from one column are equal to the values of another column!
#
# We'll add a fourth clause to our SQL query framework:
# 1. `SELECT column1, column2, ...`
# 2. `FROM table1`
# 3. `JOIN table2 ON table1.columnA = table2.columnB`
# 4. `WHERE condition;`
#
# Finally, notice that we reference the `titles` table in our query as a shorter alias, `t`. We can use this to simplify query writing, especially where typing out a full table name multiple times might be cumbersome.
#
# If we modify the `FROM` clause to be `FROM table1 as t`, then all references to `table1` in our query must instead use the alias `t` or our query will fail due to malformed syntax.
#
# Our framework now looks like this:
# 1. `SELECT t.column1, t.column2, ...`
# 2. `FROM table1 AS t`
# 3. `JOIN table2 ON table1.columnA = table2.columnB`
# 4. `WHERE condition;`
#
# Using this knowledge, let's write another `JOIN` query to select all of the revenue for Brad Pitt's movies.

# %%
# Retrieve Brad Pitt
cursor.execute(
    """
    SELECT *
    FROM people
    WHERE name = 'Brad Pitt';
    """
)
cursor.fetchall()
# Out:
# [['43ccd6ee-145e-44f0-b8b1-e06f0b2cf801',
#   'Brad Pitt',
#   'Male',
#   'White',
#   datetime.datetime(1963, 12, 18, 0, 0)]]

# %%
# Retrieve the week-by-week gross of Brad Pitt's movies
cursor.execute(
    """
    SELECT 
        r.title_id,
        r.week_number,
        r.gross,
        r.theaters,
        t.title
    FROM revenues AS r
    JOIN (
        SELECT t.id, t.title
        FROM titles AS t
        JOIN roles ON roles.title_id = t.id
        WHERE roles.person_id = '43ccd6ee-145e-44f0-b8b1-e06f0b2cf801'
    ) AS t
    ON r.title_id = t.id;
    """
)
cursor.fetchall()
# Out:
# [['14595dfb-6582-41ac-bb91-93b199dce5b0',
#   Decimal('4'),
#   Decimal('19466'),
#   Decimal('32'),
#   'By the Sea'],
#  ['14595dfb-6582-41ac-bb91-93b199dce5b0',
#   Decimal('3'),
#   Decimal('125665'),
#   Decimal('142'),
#   'By the Sea'],
#  ['14595dfb-6582-41ac-bb91-93b199dce5b0',
#   Decimal('2'),
#   Decimal('265732'),
#   Decimal('126'),
#   'By the Sea'],
#  ['14595dfb-6582-41ac-bb91-93b199dce5b0',
#   Decimal('1'),
#   Decimal('127597'),
#   Decimal('10'),
#   'By the Sea'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('17'),
#   Decimal('82252'),
#   Decimal('108'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('16'),
#   Decimal('69852'),
#   Decimal('67'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('15'),
#   Decimal('188582'),
#   Decimal('133'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('14'),
#   Decimal('397323'),
#   Decimal('222'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('13'),
#   Decimal('672744'),
#   Decimal('314'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('12'),
#   Decimal('1338265'),
#   Decimal('543'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('11'),
#   Decimal('1263111'),
#   Decimal('432'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('10'),
#   Decimal('1915904'),
#   Decimal('535'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('9'),
#   Decimal('2381361'),
#   Decimal('660'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('8'),
#   Decimal('4049999'),
#   Decimal('983'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('7'),
#   Decimal('4686636'),
#   Decimal('1351'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('6'),
#   Decimal('7892959'),
#   Decimal('1765'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('5'),
#   Decimal('8771045'),
#   Decimal('2529'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('4'),
#   Decimal('12554659'),
#   Decimal('1588'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('3'),
#   Decimal('18503730'),
#   Decimal('1585'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('2'),
#   Decimal('4550044'),
#   Decimal('1585'),
#   'The Big Short'],
#  ['8ab470a7-aebf-43c8-8c88-82536c54cc52',
#   Decimal('1'),
#   Decimal('941404'),
#   Decimal('8'),
#   'The Big Short'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('14'),
#   Decimal('62313'),
#   Decimal('103'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('13'),
#   Decimal('158806'),
#   Decimal('188'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('12'),
#   Decimal('281018'),
#   Decimal('232'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('11'),
#   Decimal('436433'),
#   Decimal('250'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('10'),
#   Decimal('344112'),
#   Decimal('238'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('9'),
#   Decimal('862422'),
#   Decimal('726'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('8'),
#   Decimal('1306529'),
#   Decimal('896'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('7'),
#   Decimal('2015231'),
#   Decimal('1059'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('6'),
#   Decimal('3098924'),
#   Decimal('994'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('5'),
#   Decimal('5119049'),
#   Decimal('2382'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('4'),
#   Decimal('8364840'),
#   Decimal('2834'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('3'),
#   Decimal('12430828'),
#   Decimal('3313'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('2'),
#   Decimal('18286973'),
#   Decimal('3173'),
#   'Fury'],
#  ['7872e670-a621-4655-9906-589462dac773',
#   Decimal('1'),
#   Decimal('33050428'),
#   Decimal('3173'),
#   'Fury'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('12'),
#   Decimal('10150'),
#   Decimal('30'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('11'),
#   Decimal('50662'),
#   Decimal('87'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('10'),
#   Decimal('2772'),
#   Decimal('3'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('9'),
#   Decimal('2261'),
#   Decimal('3'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('8'),
#   Decimal('10138'),
#   Decimal('12'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('7'),
#   Decimal('27675'),
#   Decimal('31'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('6'),
#   Decimal('56217'),
#   Decimal('51'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('5'),
#   Decimal('76391'),
#   Decimal('68'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('4'),
#   Decimal('164346'),
#   Decimal('68'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('3'),
#   Decimal('1490782'),
#   Decimal('1427'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('2'),
#   Decimal('4108568'),
#   Decimal('2424'),
#   'Killing Them Softly'],
#  ['128abc2d-39ed-46b5-a842-88f7e024fb11',
#   Decimal('1'),
#   Decimal('9023737'),
#   Decimal('2424'),
#   'Killing Them Softly'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('16'),
#   Decimal('443480'),
#   Decimal('214'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('15'),
#   Decimal('417481'),
#   Decimal('243'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('14'),
#   Decimal('475788'),
#   Decimal('290'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('13'),
#   Decimal('610795'),
#   Decimal('300'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('12'),
#   Decimal('698630'),
#   Decimal('320'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('11'),
#   Decimal('1014594'),
#   Decimal('341'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('10'),
#   Decimal('355573'),
#   Decimal('375'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('9'),
#   Decimal('838434'),
#   Decimal('764'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('8'),
#   Decimal('1231579'),
#   Decimal('764'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('7'),
#   Decimal('1378537'),
#   Decimal('1025'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('6'),
#   Decimal('2526824'),
#   Decimal('2425'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('5'),
#   Decimal('6017828'),
#   Decimal('3173'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('4'),
#   Decimal('14031154'),
#   Decimal('3411'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('3'),
#   Decimal('24342558'),
#   Decimal('3411'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('2'),
#   Decimal('33598424'),
#   Decimal('3949'),
#   'Megamind'],
#  ['cdb1473a-30fc-4ec4-8768-e1902165a93c',
#   Decimal('1'),
#   Decimal('59702174'),
#   Decimal('3944'),
#   'Megamind'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('29'),
#   Decimal('12460'),
#   Decimal('20'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('28'),
#   Decimal('24731'),
#   Decimal('32'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('27'),
#   Decimal('46141'),
#   Decimal('53'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('26'),
#   Decimal('53752'),
#   Decimal('64'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('25'),
#   Decimal('99842'),
#   Decimal('128'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('24'),
#   Decimal('190740'),
#   Decimal('228'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('23'),
#   Decimal('653742'),
#   Decimal('522'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('22'),
#   Decimal('1722593'),
#   Decimal('925'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('21'),
#   Decimal('2935957'),
#   Decimal('1065'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('20'),
#   Decimal('1571670'),
#   Decimal('411'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('19'),
#   Decimal('805642'),
#   Decimal('349'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('18'),
#   Decimal('703299'),
#   Decimal('386'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('17'),
#   Decimal('1120702'),
#   Decimal('566'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('16'),
#   Decimal('2122879'),
#   Decimal('1172'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('15'),
#   Decimal('2031316'),
#   Decimal('1231'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('14'),
#   Decimal('2424519'),
#   Decimal('761'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('13'),
#   Decimal('470523'),
#   Decimal('114'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('12'),
#   Decimal('490433'),
#   Decimal('151'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('11'),
#   Decimal('717358'),
#   Decimal('154'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('10'),
#   Decimal('370090'),
#   Decimal('301'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('9'),
#   Decimal('1078538'),
#   Decimal('414'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('8'),
#   Decimal('1759568'),
#   Decimal('1082'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('7'),
#   Decimal('3021916'),
#   Decimal('1165'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('6'),
#   Decimal('4256892'),
#   Decimal('1165'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('5'),
#   Decimal('6344527'),
#   Decimal('1411'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('4'),
#   Decimal('9503204'),
#   Decimal('1144'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('3'),
#   Decimal('6585257'),
#   Decimal('410'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('2'),
#   Decimal('2900381'),
#   Decimal('123'),
#   '12 Years a Slave'],
#  ['a8117ccf-1373-4b42-9a60-387925dc0606',
#   Decimal('1'),
#   Decimal('1259943'),
#   Decimal('19'),
#   '12 Years a Slave'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('12'),
#   Decimal('9398'),
#   Decimal('17'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('11'),
#   Decimal('8181'),
#   Decimal('21'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('10'),
#   Decimal('12428'),
#   Decimal('24'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('9'),
#   Decimal('6181'),
#   Decimal('24'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('8'),
#   Decimal('27231'),
#   Decimal('60'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('7'),
#   Decimal('35784'),
#   Decimal('71'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('6'),
#   Decimal('44238'),
#   Decimal('78'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('5'),
#   Decimal('91803'),
#   Decimal('129'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('4'),
#   Decimal('502584'),
#   Decimal('481'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('3'),
#   Decimal('1187214'),
#   Decimal('1022'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('2'),
#   Decimal('4657528'),
#   Decimal('3044'),
#   'The Counselor'],
#  ['0478a5ca-0bd6-48ea-bc14-792ad435a345',
#   Decimal('1'),
#   Decimal('10387509'),
#   Decimal('3044'),
#   'The Counselor'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('16'),
#   Decimal('51371'),
#   Decimal('75'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('15'),
#   Decimal('117612'),
#   Decimal('160'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('14'),
#   Decimal('241757'),
#   Decimal('203'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('13'),
#   Decimal('430138'),
#   Decimal('280'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('12'),
#   Decimal('598296'),
#   Decimal('374'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('11'),
#   Decimal('1896706'),
#   Decimal('1247'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('10'),
#   Decimal('483810'),
#   Decimal('239'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('9'),
#   Decimal('673888'),
#   Decimal('307'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('8'),
#   Decimal('1062501'),
#   Decimal('505'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('7'),
#   Decimal('2729670'),
#   Decimal('912'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('6'),
#   Decimal('4214416'),
#   Decimal('1440'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('5'),
#   Decimal('8118479'),
#   Decimal('2066'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('4'),
#   Decimal('14084147'),
#   Decimal('3003'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('3'),
#   Decimal('27076245'),
#   Decimal('3316'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('2'),
#   Decimal('46658381'),
#   Decimal('3405'),
#   'World War Z'],
#  ['60e99e13-404d-4ae7-93a9-c83ae02c91fa',
#   Decimal('1'),
#   Decimal('93922294'),
#   Decimal('3607'),
#   'World War Z'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('19'),
#   Decimal('50233'),
#   Decimal('81'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('18'),
#   Decimal('89298'),
#   Decimal('110'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('17'),
#   Decimal('123268'),
#   Decimal('110'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('16'),
#   Decimal('242840'),
#   Decimal('231'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('15'),
#   Decimal('343404'),
#   Decimal('250'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('14'),
#   Decimal('365012'),
#   Decimal('242'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('13'),
#   Decimal('149609'),
#   Decimal('242'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('12'),
#   Decimal('215225'),
#   Decimal('208'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('11'),
#   Decimal('809265'),
#   Decimal('1004'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('10'),
#   Decimal('347777'),
#   Decimal('187'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('9'),
#   Decimal('740657'),
#   Decimal('187'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('8'),
#   Decimal('1337335'),
#   Decimal('813'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('7'),
#   Decimal('2364179'),
#   Decimal('1278'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('6'),
#   Decimal('3406340'),
#   Decimal('1631'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('5'),
#   Decimal('5362156'),
#   Decimal('2353'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('4'),
#   Decimal('7446636'),
#   Decimal('2840'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('3'),
#   Decimal('10459080'),
#   Decimal('3018'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('2'),
#   Decimal('15784640'),
#   Decimal('2993'),
#   'Moneyball'],
#  ['a05fb48f-1450-4187-93bc-6f2cafa1d80f',
#   Decimal('1'),
#   Decimal('19501302'),
#   Decimal('2993'),
#   'Moneyball'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('22'),
#   Decimal('6147'),
#   Decimal('4'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('21'),
#   Decimal('10745'),
#   Decimal('6'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('20'),
#   Decimal('16733'),
#   Decimal('11'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('19'),
#   Decimal('41365'),
#   Decimal('29'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('18'),
#   Decimal('31743'),
#   Decimal('39'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('17'),
#   Decimal('58148'),
#   Decimal('41'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('16'),
#   Decimal('72003'),
#   Decimal('62'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('15'),
#   Decimal('134311'),
#   Decimal('86'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('14'),
#   Decimal('138689'),
#   Decimal('97'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('13'),
#   Decimal('196326'),
#   Decimal('96'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('12'),
#   Decimal('260489'),
#   Decimal('118'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('11'),
#   Decimal('410433'),
#   Decimal('170'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('10'),
#   Decimal('550790'),
#   Decimal('196'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('9'),
#   Decimal('869797'),
#   Decimal('230'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('8'),
#   Decimal('1018811'),
#   Decimal('235'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('7'),
#   Decimal('1243005'),
#   Decimal('237'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('6'),
#   Decimal('1717325'),
#   Decimal('228'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('5'),
#   Decimal('1988172'),
#   Decimal('215'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('4'),
#   Decimal('1778832'),
#   Decimal('114'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('3'),
#   Decimal('1201786'),
#   Decimal('47'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('2'),
#   Decimal('902711'),
#   Decimal('20'),
#   'The Tree of Life'],
#  ['d9915fa6-b4ae-47e0-acb2-b0106502171a',
#   Decimal('1'),
#   Decimal('631935'),
#   Decimal('4'),
#   'The Tree of Life'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('17'),
#   Decimal('41437'),
#   Decimal('61'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('16'),
#   Decimal('97757'),
#   Decimal('194'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('15'),
#   Decimal('76931'),
#   Decimal('102'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('14'),
#   Decimal('124295'),
#   Decimal('109'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('13'),
#   Decimal('198167'),
#   Decimal('233'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('12'),
#   Decimal('335229'),
#   Decimal('284'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('11'),
#   Decimal('184814'),
#   Decimal('148'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('10'),
#   Decimal('262564'),
#   Decimal('206'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('9'),
#   Decimal('487466'),
#   Decimal('436'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('8'),
#   Decimal('1283360'),
#   Decimal('968'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('7'),
#   Decimal('1973817'),
#   Decimal('1331'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('6'),
#   Decimal('3737347'),
#   Decimal('1960'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('5'),
#   Decimal('5438870'),
#   Decimal('2519'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('4'),
#   Decimal('8535813'),
#   Decimal('3215'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('3'),
#   Decimal('17567244'),
#   Decimal('3358'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('2'),
#   Decimal('26476420'),
#   Decimal('3165'),
#   'Inglourious Basterds'],
#  ['8d69bf8d-bd80-487a-8387-31be8ea0e616',
#   Decimal('1'),
#   Decimal('53703427'),
#   Decimal('3165'),
#   'Inglourious Basterds'],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('21'),
#   Decimal('39212'),
#   Decimal('45'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('20'),
#   Decimal('84285.0'),
#   Decimal('48.0'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('19'),
#   Decimal('105340'),
#   Decimal('105'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('18'),
#   Decimal('176758'),
#   Decimal('108'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('17'),
#   Decimal('232841'),
#   Decimal('189'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('16'),
#   Decimal('299753'),
#   Decimal('260.0'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('15'),
#   Decimal('397715'),
#   Decimal('311'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('14'),
#   Decimal('160474'),
#   Decimal('102'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('13'),
#   Decimal('198438.0'),
#   Decimal('123.0'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('12'),
#   Decimal('252512'),
#   Decimal('176'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('11'),
#   Decimal('526111'),
#   Decimal('407'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('10'),
#   Decimal('1389301.0'),
#   Decimal('812.0'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('9'),
#   Decimal('2056615'),
#   Decimal('1541'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('8'),
#   Decimal('4053064.0'),
#   Decimal('2010.0'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('7'),
#   Decimal('7929513.0'),
#   Decimal('2670.0'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('6'),
#   Decimal('7738381'),
#   Decimal('2670'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('5'),
#   Decimal('14023286'),
#   Decimal('2770'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('4'),
#   Decimal('30087394'),
#   Decimal('3075'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('3'),
#   Decimal('30196160'),
#   Decimal('3075'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('2'),
#   Decimal('30401714'),
#   Decimal('3075'),
#   "Ocean's Eleven"],
#  ['8c9a7a13-76ce-4c6a-acc6-621c2fe1784e',
#   Decimal('1'),
#   Decimal('50229526'),
#   Decimal('3075'),
#   "Ocean's Eleven"],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('11'),
#   Decimal('80975'),
#   Decimal('205'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('10'),
#   Decimal('156640'),
#   Decimal('259'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('9'),
#   Decimal('208030'),
#   Decimal('293'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('8'),
#   Decimal('238780'),
#   Decimal('376'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('7'),
#   Decimal('458035'),
#   Decimal('424'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('6'),
#   Decimal('926285'),
#   Decimal('475'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('5'),
#   Decimal('1465800'),
#   Decimal('834'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('4'),
#   Decimal('3351940'),
#   Decimal('2503'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('3'),
#   Decimal('5887010'),
#   Decimal('2770'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('2'),
#   Decimal('13793875'),
#   Decimal('2770'),
#   'Spy Game'],
#  ['5b895a21-6a98-4a58-a31d-27dc7d1d1e8a',
#   Decimal('1'),
#   Decimal('26800930'),
#   Decimal('2770'),
#   'Spy Game'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('13'),
#   Decimal('190086'),
#   Decimal('148'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('12'),
#   Decimal('254119'),
#   Decimal('262'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('11'),
#   Decimal('249766'),
#   Decimal('359'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('10'),
#   Decimal('371982'),
#   Decimal('425'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('9'),
#   Decimal('183515'),
#   Decimal('237'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('8'),
#   Decimal('391284'),
#   Decimal('434.0'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('7'),
#   Decimal('672787'),
#   Decimal('660'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('6'),
#   Decimal('1554834'),
#   Decimal('1328'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('5'),
#   Decimal('3327939'),
#   Decimal('2047'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('4'),
#   Decimal('6292379'),
#   Decimal('3043'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('3'),
#   Decimal('10596341'),
#   Decimal('3162'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('2'),
#   Decimal('16609838'),
#   Decimal('2959'),
#   'The Mexican'],
#  ['3abfc01f-9e82-4783-9b06-abc9e444b1a5',
#   Decimal('1'),
#   Decimal('26150163'),
#   Decimal('2951'),
#   'The Mexican'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('13'),
#   Decimal('25606'),
#   Decimal('63'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('12'),
#   Decimal('45211'),
#   Decimal('117'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('11'),
#   Decimal('58775'),
#   Decimal('152'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('10'),
#   Decimal('88300'),
#   Decimal('218'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('9'),
#   Decimal('180065'),
#   Decimal('246'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('8'),
#   Decimal('23858'),
#   Decimal('89'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('7'),
#   Decimal('42320'),
#   Decimal('129'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('6'),
#   Decimal('64834'),
#   Decimal('182'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('5'),
#   Decimal('153993'),
#   Decimal('294'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('4'),
#   Decimal('390254'),
#   Decimal('865'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('3'),
#   Decimal('1890171'),
#   Decimal('2017'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('2'),
#   Decimal('4310834'),
#   Decimal('3086'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['14fbe5b0-090e-41d0-998c-d1dd9e20453a',
#   Decimal('1'),
#   Decimal('6874477'),
#   Decimal('3086'),
#   'Sinbad: Legend of the Seven Seas'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('16'),
#   None,
#   Decimal('0'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('15'),
#   Decimal('39236'),
#   Decimal('77'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('14'),
#   Decimal('79155'),
#   Decimal('142'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('13'),
#   Decimal('147349'),
#   Decimal('209'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('12'),
#   Decimal('202062'),
#   Decimal('292'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('11'),
#   Decimal('298666'),
#   Decimal('301'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('10'),
#   Decimal('202115.0'),
#   Decimal('110'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('9'),
#   Decimal('355511'),
#   Decimal('201'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('8'),
#   Decimal('664205'),
#   Decimal('375'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('7'),
#   Decimal('1360875'),
#   Decimal('511'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('6'),
#   Decimal('2696434'),
#   Decimal('1303'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('5'),
#   Decimal('5065567'),
#   Decimal('2003'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('4'),
#   Decimal('8874795'),
#   Decimal('2750'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('3'),
#   Decimal('18663840'),
#   Decimal('3411'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('2'),
#   Decimal('32613318'),
#   Decimal('3411'),
#   'Troy'],
#  ['a5140a5e-0f48-46b1-b5fe-e2b568bbd6a7',
#   Decimal('1'),
#   Decimal('62035449'),
#   Decimal('3411'),
#   'Troy'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('27'),
#   Decimal('768'),
#   Decimal('2'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('26'),
#   Decimal('2898'),
#   Decimal('5'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('25'),
#   Decimal('8941'),
#   Decimal('13'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('24'),
#   Decimal('17021'),
#   Decimal('17'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('23'),
#   Decimal('22836'),
#   Decimal('22'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('22'),
#   Decimal('49151'),
#   Decimal('55'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('21'),
#   Decimal('51044'),
#   Decimal('60'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('20'),
#   Decimal('76830'),
#   Decimal('70'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('19'),
#   Decimal('127016'),
#   Decimal('105'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('18'),
#   Decimal('155626'),
#   Decimal('140'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('17'),
#   Decimal('187223'),
#   Decimal('188'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('16'),
#   Decimal('222791'),
#   Decimal('232'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('15'),
#   Decimal('272998'),
#   Decimal('268'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('14'),
#   Decimal('417332'),
#   Decimal('383'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('13'),
#   Decimal('574885'),
#   Decimal('351'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('12'),
#   Decimal('542733'),
#   Decimal('355'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('11'),
#   Decimal('677275'),
#   Decimal('416'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('10'),
#   Decimal('1225054'),
#   Decimal('576'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('9'),
#   Decimal('2048428'),
#   Decimal('833'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('8'),
#   Decimal('2948500'),
#   Decimal('1142'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('7'),
#   Decimal('5764426'),
#   Decimal('1916'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('6'),
#   Decimal('7900755'),
#   Decimal('2370'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('5'),
#   Decimal('7872275'),
#   Decimal('2781'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('4'),
#   Decimal('17438143'),
#   Decimal('2985'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('3'),
#   Decimal('24670617'),
#   Decimal('3040'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('2'),
#   Decimal('38027311'),
#   Decimal('3451'),
#   'Mr. & Mrs. Smith'],
#  ['1bb841e8-811d-479e-98af-a9f0a01ccd8c',
#   Decimal('1'),
#   Decimal('70660963'),
#   Decimal('3424'),
#   'Mr. & Mrs. Smith'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('22'),
#   Decimal('5851'),
#   Decimal('7'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('21'),
#   Decimal('30838'),
#   Decimal('38'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('20'),
#   Decimal('98781'),
#   Decimal('84'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('19'),
#   Decimal('232431'),
#   Decimal('176'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('18'),
#   Decimal('572241'),
#   Decimal('289'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('17'),
#   Decimal('850590'),
#   Decimal('305'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('16'),
#   Decimal('2169917'),
#   Decimal('919'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('15'),
#   Decimal('2328098'),
#   Decimal('1090'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('14'),
#   Decimal('3348902'),
#   Decimal('1090'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('13'),
#   Decimal('3079180'),
#   Decimal('889'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('12'),
#   Decimal('658796'),
#   Decimal('173'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('11'),
#   Decimal('636697'),
#   Decimal('190'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('10'),
#   Decimal('944001'),
#   Decimal('233'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('9'),
#   Decimal('784178'),
#   Decimal('208'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('8'),
#   Decimal('737121'),
#   Decimal('220'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('7'),
#   Decimal('676025'),
#   Decimal('373'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('6'),
#   Decimal('1376392'),
#   Decimal('609'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('5'),
#   Decimal('2547199'),
#   Decimal('902'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('4'),
#   Decimal('4114137'),
#   Decimal('902'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('3'),
#   Decimal('7274200'),
#   Decimal('1251'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('2'),
#   Decimal('1285883'),
#   Decimal('35'),
#   'Babel'],
#  ['cfe42cca-3138-49df-97be-487fc7d8745f',
#   Decimal('1'),
#   Decimal('551379'),
#   Decimal('7'),
#   'Babel'],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('15'),
#   Decimal('40172'),
#   Decimal('77'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('14'),
#   Decimal('63301'),
#   Decimal('108'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('13'),
#   Decimal('116594'),
#   Decimal('137'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('12'),
#   Decimal('173302'),
#   Decimal('218'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('11'),
#   Decimal('324271'),
#   Decimal('297'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('10'),
#   Decimal('472942'),
#   Decimal('321'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('9'),
#   Decimal('209739'),
#   Decimal('160'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('8'),
#   Decimal('676907'),
#   Decimal('340'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('7'),
#   Decimal('1556557'),
#   Decimal('750'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('6'),
#   Decimal('2998560'),
#   Decimal('1244'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('5'),
#   Decimal('4902429'),
#   Decimal('1465'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('4'),
#   Decimal('9585372'),
#   Decimal('2241'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('3'),
#   Decimal('16366269'),
#   Decimal('3361'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('2'),
#   Decimal('28962973'),
#   Decimal('3565'),
#   "Ocean's Thirteen"],
#  ['841cbf11-131b-4e26-88d5-e9066596a1ad',
#   Decimal('1'),
#   Decimal('50705336'),
#   Decimal('3565'),
#   "Ocean's Thirteen"],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('19'),
#   Decimal('11458'),
#   Decimal('9'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('18'),
#   Decimal('2563'),
#   Decimal('4'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('17'),
#   Decimal('8962'),
#   Decimal('8'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('16'),
#   Decimal('5449'),
#   Decimal('7'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('15'),
#   Decimal('8262'),
#   Decimal('10'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('14'),
#   Decimal('7691'),
#   Decimal('10'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('13'),
#   Decimal('23495'),
#   Decimal('30'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('12'),
#   Decimal('35269'),
#   Decimal('35'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('11'),
#   Decimal('36757'),
#   Decimal('30'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('10'),
#   Decimal('31862'),
#   Decimal('30'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('9'),
#   Decimal('106364'),
#   Decimal('84'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('8'),
#   Decimal('225637'),
#   Decimal('130'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('7'),
#   Decimal('336551'),
#   Decimal('212'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('6'),
#   Decimal('640503'),
#   Decimal('294'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('5'),
#   Decimal('780782'),
#   Decimal('301'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('4'),
#   Decimal('675592'),
#   Decimal('163'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('3'),
#   Decimal('633754'),
#   Decimal('61'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('2'),
#   Decimal('129812'),
#   Decimal('5'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['be65097c-5382-4f92-a9b4-ea1eaab214d9',
#   Decimal('1'),
#   Decimal('208386'),
#   Decimal('5'),
#   'The Assassination of Jesse James by the Coward Robert Ford'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('15'),
#   Decimal('32770'),
#   Decimal('44'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('14'),
#   Decimal('53478'),
#   Decimal('57'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('13'),
#   Decimal('69526'),
#   Decimal('78'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('12'),
#   Decimal('116685'),
#   Decimal('97'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('11'),
#   Decimal('165903'),
#   Decimal('97'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('10'),
#   Decimal('261939'),
#   Decimal('207'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('9'),
#   Decimal('517380'),
#   Decimal('270'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('8'),
#   Decimal('618184'),
#   Decimal('327'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('7'),
#   Decimal('990138'),
#   Decimal('422'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('6'),
#   Decimal('1507971'),
#   Decimal('708'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('5'),
#   Decimal('2939621'),
#   Decimal('1406'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('4'),
#   Decimal('5523778'),
#   Decimal('2397'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('3'),
#   Decimal('8186852'),
#   Decimal('2649'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('2'),
#   Decimal('14264158'),
#   Decimal('2657'),
#   'Burn After Reading'],
#  ['f4b875fd-a74d-436b-b7b8-455fabfadc1b',
#   Decimal('1'),
#   Decimal('25106964'),
#   Decimal('2651'),
#   'Burn After Reading'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('17'),
#   Decimal('77405'),
#   Decimal('111'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('16'),
#   Decimal('121018'),
#   Decimal('156'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('15'),
#   Decimal('194828'),
#   Decimal('213'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('14'),
#   Decimal('301213'),
#   Decimal('246'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('13'),
#   Decimal('178272'),
#   Decimal('206'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('12'),
#   Decimal('375067'),
#   Decimal('281'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('11'),
#   Decimal('599625'),
#   Decimal('401'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('10'),
#   Decimal('1060819'),
#   Decimal('558'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('9'),
#   Decimal('1621990'),
#   Decimal('754'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('8'),
#   Decimal('2334316'),
#   Decimal('909'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('7'),
#   Decimal('2996676'),
#   Decimal('1478'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('6'),
#   Decimal('4719082'),
#   Decimal('2126'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('5'),
#   Decimal('7885452'),
#   Decimal('2263'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('4'),
#   Decimal('8018826'),
#   Decimal('2223'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('3'),
#   Decimal('12144857'),
#   Decimal('2947'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('2'),
#   Decimal('24274042'),
#   Decimal('2988'),
#   'The Curious Case of Benjamin Button'],
#  ['5d38b938-d766-4ad2-a413-51624cc8f9e9',
#   Decimal('1'),
#   Decimal('48734007'),
#   Decimal('2988'),
#   'The Curious Case of Benjamin Button'],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('15'),
#   Decimal('37637'),
#   Decimal('73'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('14'),
#   Decimal('69863'),
#   Decimal('115'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('13'),
#   Decimal('126539'),
#   Decimal('140'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('12'),
#   Decimal('217266'),
#   Decimal('202'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('11'),
#   Decimal('519999'),
#   Decimal('463'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('10'),
#   Decimal('277353'),
#   Decimal('201'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('9'),
#   Decimal('469040'),
#   Decimal('407'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('8'),
#   Decimal('906654'),
#   Decimal('702'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('7'),
#   Decimal('1910193'),
#   Decimal('1275'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('6'),
#   Decimal('4059687'),
#   Decimal('2105'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('5'),
#   Decimal('6948460'),
#   Decimal('3010'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('4'),
#   Decimal('12428444'),
#   Decimal('3290'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('3'),
#   Decimal('19374096'),
#   Decimal('3290'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('2'),
#   Decimal('27798670'),
#   Decimal('3290'),
#   "Ocean's Twelve"],
#  ['88a9f9bb-57c9-446c-afd3-c8a1b1199b12',
#   Decimal('1'),
#   Decimal('50400379'),
#   Decimal('3290'),
#   "Ocean's Twelve"],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('14'),
#   Decimal('358037'),
#   Decimal('219'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('13'),
#   Decimal('695540'),
#   Decimal('254'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('12'),
#   Decimal('1171265'),
#   Decimal('402'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('11'),
#   Decimal('1998163'),
#   Decimal('603'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('10'),
#   Decimal('2841855'),
#   Decimal('851'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('9'),
#   Decimal('2053845'),
#   Decimal('851'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('8'),
#   Decimal('5287090'),
#   Decimal('1240'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('7'),
#   Decimal('4006923'),
#   Decimal('1240'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('6'),
#   Decimal('6734386'),
#   Decimal('1444'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('5'),
#   Decimal('4706743'),
#   Decimal('1444'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('4'),
#   Decimal('10946720'),
#   Decimal('1444'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('3'),
#   Decimal('8005163'),
#   Decimal('1444'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('2'),
#   None,
#   Decimal('1'),
#   'Snatch'],
#  ['72ef4f94-a20d-4322-8016-bdb98cf5c529',
#   Decimal('1'),
#   Decimal('27932'),
#   Decimal('1'),
#   'Snatch'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('9'),
#   Decimal('1801283'),
#   Decimal('743'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('8'),
#   Decimal('2041209'),
#   Decimal('816'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('7'),
#   Decimal('3018783'),
#   Decimal('907'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('6'),
#   Decimal('3557014'),
#   Decimal('1081'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('5'),
#   Decimal('4114423'),
#   Decimal('1166'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('4'),
#   Decimal('4148272'),
#   Decimal('1180'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('3'),
#   Decimal('4666717'),
#   Decimal('1180'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('2'),
#   Decimal('6231320'),
#   Decimal('1180'),
#   'Thelma & Louise'],
#  ['98b576d8-3ed9-4b26-b36e-0ea5498893ca',
#   Decimal('1'),
#   Decimal('7743338'),
#   Decimal('1179'),
#   'Thelma & Louise'],
#  ['50eaa2e4-077c-471b-8cc0-6fbf4e2b4e56',
#   Decimal('2'),
#   Decimal('3737826'),
#   Decimal('1600'),
#   'Cool World'],
#  ['50eaa2e4-077c-471b-8cc0-6fbf4e2b4e56',
#   Decimal('1'),
#   Decimal('8059659'),
#   Decimal('1448'),
#   'Cool World'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('14'),
#   Decimal('1338585'),
#   Decimal('740'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('13'),
#   Decimal('1022337'),
#   Decimal('740'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('12'),
#   None,
#   Decimal('665'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('11'),
#   Decimal('1173055'),
#   Decimal('665'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('10'),
#   Decimal('967496'),
#   Decimal('777'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('9'),
#   Decimal('1836785'),
#   Decimal('1043'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('8'),
#   Decimal('3686633'),
#   Decimal('1080'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('7'),
#   Decimal('4473367'),
#   Decimal('1080'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('6'),
#   Decimal('4986846'),
#   Decimal('1062'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('5'),
#   Decimal('6747671'),
#   Decimal('1008'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('4'),
#   Decimal('5839514'),
#   Decimal('795'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('3'),
#   Decimal('2143941'),
#   Decimal('130'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('2'),
#   Decimal('669571'),
#   Decimal('24'),
#   'A River Runs Through It'],
#  ['84af2f54-c181-4ba5-8372-865cb62394c4',
#   Decimal('1'),
#   Decimal('387477'),
#   Decimal('12'),
#   'A River Runs Through It'],
#  ['6e7c1860-beca-4eb8-ab20-77befaea694c',
#   Decimal('1'),
#   Decimal('1434451'),
#   Decimal('359'),
#   'Kalifornia'],
#  ['3403e726-50b5-4ff2-8792-31ead1c0233c',
#   Decimal('2'),
#   Decimal('656899'),
#   Decimal('1021'),
#   'The Favor'],
#  ['3403e726-50b5-4ff2-8792-31ead1c0233c',
#   Decimal('1'),
#   Decimal('1909419'),
#   Decimal('1029'),
#   'The Favor'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('8'),
#   Decimal('1726931'),
#   Decimal('995'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('7'),
#   Decimal('1857262'),
#   Decimal('995'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('6'),
#   Decimal('2136486'),
#   Decimal('1589'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('5'),
#   Decimal('3020999'),
#   Decimal('2086'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('4'),
#   Decimal('6436187'),
#   Decimal('2086'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('3'),
#   Decimal('14294250'),
#   Decimal('2604'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('2'),
#   Decimal('25422874'),
#   Decimal('2604'),
#   'Interview with the Vampire'],
#  ['922d27a4-3eea-433e-8d3e-b4a3af205e13',
#   Decimal('1'),
#   Decimal('46181836'),
#   Decimal('2604'),
#   'Interview with the Vampire'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('12'),
#   Decimal('1654809'),
#   Decimal('1018'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('11'),
#   Decimal('2373432'),
#   Decimal('1203'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('10'),
#   Decimal('3255591'),
#   Decimal('1677'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('9'),
#   Decimal('4715555'),
#   Decimal('1941'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('8'),
#   Decimal('5867849'),
#   Decimal('2038'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('7'),
#   Decimal('6527890'),
#   Decimal('2038'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('6'),
#   Decimal('8314718'),
#   Decimal('2038'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('5'),
#   Decimal('11538296'),
#   Decimal('2038'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('4'),
#   Decimal('16714827'),
#   Decimal('2005'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('3'),
#   Decimal('375683'),
#   Decimal('7'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('2'),
#   Decimal('351513'),
#   Decimal('7'),
#   'Legends of the Fall'],
#  ['43c840ff-9a85-496b-b931-9c4bf3bda6b1',
#   Decimal('1'),
#   Decimal('210093'),
#   Decimal('6'),
#   'Legends of the Fall'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('7'),
#   Decimal('2322995'),
#   Decimal('1434'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('6'),
#   Decimal('3754815'),
#   Decimal('1612'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('5'),
#   Decimal('5290425'),
#   Decimal('1629'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('4'),
#   Decimal('8114335'),
#   Decimal('1610'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('3'),
#   Decimal('13787130'),
#   Decimal('1582'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('2'),
#   Decimal('18798865'),
#   Decimal('1533'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['c98909fe-6d24-42be-9302-8ea01e760635',
#   Decimal('1'),
#   Decimal('363389'),
#   Decimal('3'),
#   'Twelve Monkeys (12 Monkeys)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('11'),
#   Decimal('1673303'),
#   Decimal('1120'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('10'),
#   Decimal('2074102'),
#   Decimal('902'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('9'),
#   Decimal('2094057'),
#   Decimal('1463'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('8'),
#   Decimal('3160575'),
#   Decimal('1818'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('7'),
#   Decimal('4805623'),
#   Decimal('2007'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('6'),
#   Decimal('5322379'),
#   Decimal('2252'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('5'),
#   Decimal('8862620'),
#   Decimal('2528'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('4'),
#   Decimal('11323568'),
#   Decimal('2511'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('3'),
#   Decimal('14029787'),
#   Decimal('2511'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('2'),
#   Decimal('16651975'),
#   Decimal('2472'),
#   'Seven (Se7en)'],
#  ['882c0b33-1940-4b03-8a69-1550827df12c',
#   Decimal('1'),
#   Decimal('18427014'),
#   Decimal('2441'),
#   'Seven (Se7en)'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('8'),
#   Decimal('327225'),
#   Decimal('447'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('7'),
#   Decimal('1212735'),
#   Decimal('1075'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('6'),
#   Decimal('2232119'),
#   Decimal('1582'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('5'),
#   Decimal('2994246'),
#   Decimal('1818'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('4'),
#   Decimal('4909058'),
#   Decimal('2080'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('3'),
#   Decimal('10332175'),
#   Decimal('2080'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('2'),
#   Decimal('12786979'),
#   Decimal('2080'),
#   'Sleepers'],
#  ['e97d48ed-b926-4779-b858-783653611a4e',
#   Decimal('1'),
#   Decimal('16746377'),
#   Decimal('1915'),
#   'Sleepers'],
#  ['25d940b1-859c-49cf-ae49-0e5730034153',
#   Decimal('5'),
#   Decimal('1154808'),
#   Decimal('1270'),
#   "The Devil's Own"],
#  ['25d940b1-859c-49cf-ae49-0e5730034153',
#   Decimal('4'),
#   Decimal('3154126'),
#   Decimal('2004'),
#   "The Devil's Own"],
#  ['25d940b1-859c-49cf-ae49-0e5730034153',
#   Decimal('3'),
#   Decimal('5338954'),
#   Decimal('2355'),
#   "The Devil's Own"],
#  ['25d940b1-859c-49cf-ae49-0e5730034153',
#   Decimal('2'),
#   Decimal('8796902'),
#   Decimal('2504'),
#   "The Devil's Own"],
#  ['25d940b1-859c-49cf-ae49-0e5730034153',
#   Decimal('1'),
#   Decimal('22574814'),
#   Decimal('2504'),
#   "The Devil's Own"],
#  ['b34ebfd2-5fe8-4c90-a161-2e194b893718',
#   Decimal('6'),
#   Decimal('1202033'),
#   Decimal('968'),
#   'Seven Years in Tibet'],
#  ['b34ebfd2-5fe8-4c90-a161-2e194b893718',
#   Decimal('5'),
#   Decimal('2842114.0'),
#   Decimal('1562.0'),
#   'Seven Years in Tibet'],
#  ['b34ebfd2-5fe8-4c90-a161-2e194b893718',
#   Decimal('4'),
#   Decimal('4321257.0'),
#   Decimal('2103.0'),
#   'Seven Years in Tibet'],
#  ['b34ebfd2-5fe8-4c90-a161-2e194b893718',
#   Decimal('3'),
#   Decimal('6154809'),
#   Decimal('2103'),
#   'Seven Years in Tibet'],
#  ['b34ebfd2-5fe8-4c90-a161-2e194b893718',
#   Decimal('2'),
#   Decimal('8250550.0'),
#   Decimal('2103.0'),
#   'Seven Years in Tibet'],
#  ['b34ebfd2-5fe8-4c90-a161-2e194b893718',
#   Decimal('1'),
#   Decimal('13293985'),
#   Decimal('2103'),
#   'Seven Years in Tibet'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('13'),
#   Decimal('48925'),
#   Decimal('103'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('12'),
#   Decimal('131945'),
#   Decimal('239'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('11'),
#   Decimal('183240'),
#   Decimal('295'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('10'),
#   Decimal('243450'),
#   Decimal('338'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('9'),
#   Decimal('347840'),
#   Decimal('544.0'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('8'),
#   Decimal('410230'),
#   Decimal('543.0'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('7'),
#   None,
#   Decimal('0'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('6'),
#   Decimal('683240'),
#   Decimal('1102'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('5'),
#   Decimal('2127475'),
#   Decimal('1872.0'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('4'),
#   Decimal('2976700.0'),
#   Decimal('2188.0'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('3'),
#   Decimal('6819455.0'),
#   Decimal('2527.0'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('2'),
#   Decimal('11423235'),
#   Decimal('2511'),
#   'Meet Joe Black'],
#  ['9d077930-a7f2-498e-b8c8-e7e590698d2d',
#   Decimal('1'),
#   Decimal('18559830'),
#   Decimal('2503'),
#   'Meet Joe Black'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('15'),
#   Decimal('37081'),
#   Decimal('81'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('14'),
#   Decimal('34626'),
#   Decimal('98'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('13'),
#   Decimal('213504'),
#   Decimal('139'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('11'),
#   Decimal('51163'),
#   Decimal('150'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('10'),
#   Decimal('246602'),
#   Decimal('282.0'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('9'),
#   Decimal('292717'),
#   Decimal('384.0'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('8'),
#   Decimal('358623'),
#   Decimal('397'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('7'),
#   Decimal('323998'),
#   Decimal('235'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('6'),
#   Decimal('613073'),
#   Decimal('363'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('5'),
#   Decimal('1468946'),
#   Decimal('741.0'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('4'),
#   Decimal('3510606'),
#   Decimal('1603'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('3'),
#   Decimal('5122385'),
#   Decimal('1943'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('2'),
#   Decimal('8807772'),
#   Decimal('1966'),
#   'Fight Club'],
#  ['eb95284f-acc4-4525-b6ba-37f8bd186fe1',
#   Decimal('1'),
#   Decimal('15555847'),
#   Decimal('1963.0'),
#   'Fight Club'],
#  ['4deebcb0-b0fd-4ddd-8feb-9605b05cfe95',
#   Decimal('5'),
#   Decimal('332183'),
#   Decimal('157'),
#   'Allied'],
#  ['4deebcb0-b0fd-4ddd-8feb-9605b05cfe95',
#   Decimal('4'),
#   Decimal('1898105'),
#   Decimal('414'),
#   'Allied'],
#  ['4deebcb0-b0fd-4ddd-8feb-9605b05cfe95',
#   Decimal('3'),
#   Decimal('5575465'),
#   Decimal('3018'),
#   'Allied'],
#  ['4deebcb0-b0fd-4ddd-8feb-9605b05cfe95',
#   Decimal('2'),
#   Decimal('9756020'),
#   Decimal('3160'),
#   'Allied'],
#  ['4deebcb0-b0fd-4ddd-8feb-9605b05cfe95',
#   Decimal('1'),
#   Decimal('16853128'),
#   Decimal('3160'),
#   'Allied']]

# %% [markdown]
# What the heck is going on up there? Well, it turns out that you can `JOIN` not just tables, but also other queries!
#
# So, we took our query from the previous example, which gives us the list of Brad Pitt's movies, and we joined it with the `revenues` table to get the week-by-week revenues of all of those movies.
#
# Notice the same structure for applying a `JOIN` and for aliasing tables with `AS`!

# %% [markdown]
# ### One more thing...

# %% [markdown]
# ![One more thing](https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/03/One-More-Thing-trademark.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1)

# %% [markdown]
# There's a library that comes pre-installed with Python Anaconda called `pandas` which can give you superpowers when it comes to performing data analysis.
#
# Let's take a look at how we can use `pandas` and our knowledge of SQL to really do some cool stuff.

# %%
# Import the package — notice that we can also alias here!
import pandas as pd

# %%
# Let's take the SQL from above and assign it to a variable
SQL_FOR_PANDAS = """
    SELECT 
        r.title_id,
        r.week_number,
        r.gross,
        r.theaters,
        t.title
    FROM revenues AS r
    JOIN (
        SELECT t.id, t.title
        FROM titles AS t
        JOIN roles ON roles.title_id = t.id
        WHERE roles.person_id = '43ccd6ee-145e-44f0-b8b1-e06f0b2cf801'
    ) AS t
    ON r.title_id = t.id;
"""

# %% [markdown]
# It turns out that `pandas` has a function called `pandas.read_sql` which takes two parameters, the SQL query itself and a connection to a database. What happens when we pass that in?
#
# Try running the below cell.

# %%
dataframe = pd.read_sql(SQL_FOR_PANDAS, connection)
dataframe
# Out:
#                                  title_id  week_number       gross  theaters  \
# 0    14595dfb-6582-41ac-bb91-93b199dce5b0          4.0     19466.0      32.0
# 1    14595dfb-6582-41ac-bb91-93b199dce5b0          3.0    125665.0     142.0
# 2    14595dfb-6582-41ac-bb91-93b199dce5b0          2.0    265732.0     126.0
# 3    14595dfb-6582-41ac-bb91-93b199dce5b0          1.0    127597.0      10.0
# 4    8ab470a7-aebf-43c8-8c88-82536c54cc52         17.0     82252.0     108.0
# ..                                    ...          ...         ...       ...
# 508  4deebcb0-b0fd-4ddd-8feb-9605b05cfe95          5.0    332183.0     157.0
# 509  4deebcb0-b0fd-4ddd-8feb-9605b05cfe95          4.0   1898105.0     414.0
# 510  4deebcb0-b0fd-4ddd-8feb-9605b05cfe95          3.0   5575465.0    3018.0
# 511  4deebcb0-b0fd-4ddd-8feb-9605b05cfe95          2.0   9756020.0    3160.0
# 512  4deebcb0-b0fd-4ddd-8feb-9605b05cfe95          1.0  16853128.0    3160.0
#
#              title
# 0       By the Sea
# 1       By the Sea
# 2       By the Sea
# 3       By the Sea
# 4    The Big Short
# ..             ...
# 508         Allied
# 509         Allied
# 510         Allied
# 511         Allied
# 512         Allied
#
# [513 rows x 5 columns]

# %% [markdown]
# Look at that! `pandas` gives us a tabular view of the data that we just queried from a SQL database hosted on AWS!
#
# But can we do anything with this data?
#
# I want to convince you that `pandas` is trivially capable of performing powerful analysis that oftentimes is difficult or even impossible to script in Excel.
#
# Consider the question:
#
# **"For each of Brad Pitt's limited release films (premiering in less than 100 theaters in its first week), how many eventually went on to achieve a peak weekly box office of over $10 million?"**

# %%
limited_releases = dataframe[(dataframe['week_number'] == 1.0) & (dataframe['theaters'] < 100)]['title']
for movie in limited_releases:
    weekly_revenues = dataframe[dataframe['title'] == movie]
    peak = weekly_revenues['gross'].idxmax()
    r = weekly_revenues.loc[[peak]].values[0]
    if r[2] > 10_000_000:
        print(f'{r[4]} peaked in week {r[1]} with ${r[2]} in {r[3]} theaters.')
# Out:
# The Big Short peaked in week 3.0 with $18503730.0 in 1585.0 theaters.
# Snatch peaked in week 4.0 with $10946720.0 in 1444.0 theaters.
# Legends of the Fall peaked in week 4.0 with $16714827.0 in 2005.0 theaters.
# Twelve Monkeys (12 Monkeys) peaked in week 2.0 with $18798865.0 in 1533.0 theaters.

# %% [markdown]
# Just ... Se7en(!) lines of code and we have our answer.
#
# For more complex analysis, we'll have to brush up on our Python skills, and we'll have to dive deeper into the [documentation](https://pandas.pydata.org/docs/) for `pandas`.
#
# But that's for another day.
